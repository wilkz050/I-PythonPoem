# %%
#NASA Fireball Occurrences API 

import requests
import json
import getpass

# %%
api_key = getpass.getpass('api key:')
# Out:
# api key: ········

# %%
nasa_api_url = 'https://ssd-api.jpl.nasa.gov/fireball.api'

# %%
response = requests.get(nasa_api_url)

fireball_data = response.json()

# %%
print(type(fireball_data))
# Out:
# <class 'dict'>

# %%
fireball_data
# Out:
# {'signature': {'version': '1.0', 'source': 'NASA/JPL Fireball Data API'},
#  'count': '947',
#  'fields': ['date',
#   'energy',
#   'impact-e',
#   'lat',
#   'lat-dir',
#   'lon',
#   'lon-dir',
#   'alt',
#   'vel'],
#  'data': [['2023-02-19 06:15:34',
#    '20.3',
#    '0.57',
#    '7.9',
#    'N',
#    '109.9',
#    'E',
#    '37.0',
#    '23.0'],
#   ['2023-02-14 22:55:25',
#    '18.4',
#    '0.52',
#    '48.0',
#    'S',
#    '53.3',
#    'W',
#    '32.3',
#    '15.6'],
#   ['2023-02-02 20:49:22',
#    '3.0',
#    '0.1',
#    '26.2',
#    'S',
#    '143.1',
#    'W',
#    '33.0',
#    None],
#   ['2023-01-22 17:11:43',
#    '2.0',
#    '0.073',
#    '3.5',
#    'N',
#    '76.2',
#    'W',
#    '61.0',
#    None],
#   ['2023-01-17 06:56:59',
#    '2.9',
#    '0.1',
#    '33.1',
#    'N',
#    '173.7',
#    'W',
#    '38.0',
#    '14.2'],
#   ['2023-01-11 23:59:50',
#    '4.6',
#    '0.15',
#    '31.5',
#    'N',
#    '18.6',
#    'E',
#    '33.5',
#    '17.5'],
# ...

# %%
# Documentation: NASA has some fantastic APIs for daily space data.
# I was surpised to learn how truly often fireballs (unusually bright meteors!)
# come near earth, over the years.
